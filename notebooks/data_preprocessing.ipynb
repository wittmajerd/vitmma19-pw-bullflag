# %%
import torch
import sys
import os
import json
import pandas as pd
import numpy as np
from datetime import datetime, timezone

# %% [markdown]
# Igazából ha minden címkéhez hozzá akarjuk adni a pole-t, akkor a label előtti dolgokat kell nézni hogy ott van-e pole és azt hozzáadni.
# Ha pedig el akarjuk tüntetni a poleokat, akkor a label elejét kell megnézni és ha ott van pole az első pár gyertyán akkor azt kiszedjük. Ezt akár lehet label arányosan csinálni hogy pl első 10%ot nézzük meg és abból azt a rész kiszedjük ami a legnagyobb meredekségű és abs álép egy határt.

# %%
from typing import List, Dict
import numpy as np
import pandas as pd

def extend_labels_with_pole(
    ohlc_df: pd.DataFrame,
    labels: List[Dict],
    price_col: str = "close",
    timestamp_col: str = "timestamp",

    min_bar_slope: float = 0.001,      # ~0.1% move per bar
    min_total_gain: float = 0.01,      # ~1% pole gain
    max_pole_bars: int = 25
) -> List[Dict]:
    """
    For each label interval, scan backward to attach a pole if a steep move precedes the flag.
    Thresholds (`min_bar_slope`, `min_total_gain`) are derived dynamically from the label's own
    price action (percentiles of recent bar slopes and cumulative gains).
    """
    df = ohlc_df.copy()
    df = df.sort_values(timestamp_col).reset_index(drop=True)

    ts_values = df[timestamp_col].to_numpy()
    price = df[price_col].to_numpy()

    def timestamp_to_idx(ts):
        idx = np.searchsorted(ts_values, ts)
        if idx >= len(ts_values) or ts_values[idx] != ts:
            return None
        return idx

    updated_labels = []
    for entry in labels:
        start_idx = timestamp_to_idx(entry["start"])
        end_idx = timestamp_to_idx(entry["end"])
        if start_idx is None or end_idx is None:
            entry = {**entry, "pole_start": entry["start"], "pole_added": False, "pole_gain": 0.0}
            updated_labels.append(entry)
            continue

        direction = 1 if "bull" in entry["label"].lower() else -1
        pole_start_idx = start_idx
        steps = 0

        while pole_start_idx > 0 and steps < max_pole_bars:
            prev_idx = pole_start_idx - 1
            bar_return = direction * ((price[pole_start_idx] - price[prev_idx]) / price[prev_idx])
            if bar_return < min_bar_slope:
                break
            pole_start_idx = prev_idx
            steps += 1

        total_gain = direction * ((price[start_idx] - price[pole_start_idx]) / price[pole_start_idx])
        if total_gain >= min_total_gain and pole_start_idx != start_idx:
            pole_ts = ts_values[pole_start_idx].isoformat()
            updated_labels.append({
                **entry,
                "pole_start": pd.to_datetime(pole_ts, utc=True),
                "pole_added": True,
                "pole_gain": float(total_gain)
            })
        else:
            updated_labels.append({
                **entry,
                "pole_start": pd.to_datetime(entry["start"], utc=True),
                "pole_added": False,
                "pole_gain": float(total_gain)
            })

    return updated_labels

# %%
def extend_labels_with_pole(
    ohlc_df: pd.DataFrame,
    labels: List[Dict],
    price_col: str = "close",
    timestamp_col: str = "timestamp",
    max_pole_bars: int = 25,
    label_window: int = 5,
    slope_multiplier: float = 1.25,
    gain_multiplier: float = 1.15,
    default_min_bar_slope: float = 0.0001,
    default_min_total_gain: float = 0.005,
) -> List[Dict]:
    df = ohlc_df.copy().sort_values(timestamp_col).reset_index(drop=True)
    df[timestamp_col] = pd.to_datetime(df[timestamp_col], utc=True)

    ts_values = df[timestamp_col].to_numpy()
    price = df[price_col].to_numpy()

    def timestamp_to_idx(ts):
        idx = np.searchsorted(ts_values, ts)
        if idx >= len(ts_values) or ts_values[idx] != ts:
            return None
        return idx

    # ezt a logikát erőteljesen át kell gondolni mert lehet pont ellentétes irányú néha működik néha nem stb
    def label_threshold(entry):
        start_idx = timestamp_to_idx(entry["start"])
        end_idx = timestamp_to_idx(entry["end"])
        if start_idx is None or end_idx is None or end_idx <= start_idx:
            return default_min_bar_slope, default_min_total_gain

        direction = 1 if "bull" in entry["label"].lower() else -1
        last_idx = min(start_idx + label_window, end_idx)
        bar_slopes = []
        for i in range(start_idx + 1, last_idx + 1):
            bar_return = direction * ((price[i] - price[i - 1]) / price[i - 1])
            if bar_return > 0:
                bar_slopes.append(bar_return)

        base_slope = np.median(bar_slopes) if bar_slopes else default_min_bar_slope
        label_gain = direction * ((price[last_idx] - price[start_idx]) / price[start_idx])
        base_gain = label_gain if label_gain > 0 else default_min_total_gain

        return base_slope * slope_multiplier, base_gain * gain_multiplier

    updated_labels = []
    for entry in labels:
        min_bar_slope, min_total_gain = label_threshold(entry)

        start_idx = timestamp_to_idx(entry["start"])
        end_idx = timestamp_to_idx(entry["end"])
        if start_idx is None or end_idx is None:
            updated_labels.append({**entry, "pole_start": entry["start"], "pole_added": False, "pole_gain": 0.0})
            continue

        direction = 1 if "bull" in entry["label"].lower() else -1
        pole_start_idx = start_idx
        steps = 0

        while pole_start_idx > 0 and steps < max_pole_bars:
            prev_idx = pole_start_idx - 1
            bar_return = direction * ((price[pole_start_idx] - price[prev_idx]) / price[prev_idx])
            if bar_return < min_bar_slope:
                break
            pole_start_idx = prev_idx
            steps += 1

        total_gain = direction * ((price[start_idx] - price[pole_start_idx]) / price[pole_start_idx])
        if total_gain >= min_total_gain and pole_start_idx != start_idx:
            updated_labels.append({
                **entry,
                "pole_start": ts_values[pole_start_idx],
                "pole_added": True,
                "pole_gain": float(total_gain),
            })
        else:
            print(f"Bar Return: {bar_return} Min Bar Slope: {min_bar_slope}, Total gain: {total_gain} Min Total Gain: {min_total_gain}")
            updated_labels.append({
                **entry,
                "pole_start": entry["start"],
                "pole_added": False,
                "pole_gain": float(total_gain),
            })

    return updated_labels

# %%
data = data_with_labels["VWXUD6/XAUUSD_5m_001.csv"]['data']
labels = data_with_labels["VWXUD6/XAUUSD_5m_001.csv"]['labels']

extended_labels = extend_labels_with_pole(data, labels)
extended_labels

# %% [markdown]
# Ezek néha működtek néha nem úgyhogy inkább nem használtam végül. Még fejleszteni, finomítani vagy pont egyszerűsíteni kéne az algoritmust.

# %%
summary_rows = []
for file_name, content in data_with_labels.items():
    df = content["data"].copy()
    df["timestamp"] = pd.to_datetime(df["timestamp"], utc=True)
    total_span = (df["timestamp"].max() - df["timestamp"].min()).total_seconds()
    label_durations = {}
    total_label_sec = 0.0
    for label in content["labels"]:
        if label["start"] is None or label["end"] is None:
            continue
        duration = (pd.to_datetime(label["end"], utc=True) - pd.to_datetime(label["start"], utc=True)).total_seconds()
        label_name = label["label"]
        label_durations[label_name] = label_durations.get(label_name, 0.0) + duration
        total_label_sec += max(duration, 0.0)
    coverage = (total_label_sec / total_span) if total_span > 0 else 0.0
    summary_rows.append({
        "file": file_name,
        "rows": len(df),
        "span_sec": total_span,
        "label_sec": total_label_sec,
        "coverage": coverage,
        "label_breakdown": label_durations,
    })
summary_df = pd.DataFrame(summary_rows).sort_values("coverage", ascending=False)
print(summary_df[["file", "rows", "span_sec", "label_sec", "coverage"]].to_string(index=False))
for idx, row in summary_df.iterrows():
    print(f"{row['file']} label breakdown:", row["label_breakdown"])
# Out:
#                                           file   rows    span_sec  label_sec  coverage
#                    TYEGJ8/EURUSD_15min_001.csv    452    586800.0   347400.0  0.592025
#                     TYEGJ8/EURUSD_5min_002.csv   1355    587400.0   178500.0  0.303882
#                    IV92EM/EURUSD_15min_001.csv   8201  10539900.0  2279700.0  0.216292
# GFTYRV/EURUSDX_2025-10-25_to_2025-10-29_5m.csv    863    258900.0    50700.0  0.195829
#                      TYEGJ8/US500_1min_003.csv   1839    535380.0   102720.0  0.191864
#                        W241KQ/EURUSD_15min.csv 143054 181578600.0 32354100.0  0.178182
# GFTYRV/EURUSDX_2025-10-30_to_2025-10-30_5m.csv    136     40500.0     7200.0  0.177778
# GFTYRV/EURUSDX_2025-09-15_to_2025-09-19_5m.csv   1365    426300.0    52800.0  0.123856
# GFTYRV/EURUSDX_2025-09-10_to_2025-09-14_5m.csv    846    253500.0    23700.0  0.093491
#                 AS76HW/XAU_1m_data_limited.csv 999999 149316360.0 13838520.0  0.092679
# GFTYRV/EURUSDX_2025-10-10_to_2025-10-14_5m.csv    846    431700.0    37500.0  0.086866
#     GFTYRV/NDX_2025-09-20_to_2025-09-24_5m.csv    234    195900.0    16800.0  0.085758
#     GFTYRV/NDX_2025-09-25_to_2025-09-29_5m.csv    234    368700.0    25800.0  0.069976
# GFTYRV/EURUSDX_2025-09-25_to_2025-09-29_5m.csv    846    431700.0    30000.0  0.069493
#                         W241KQ/EURUSD_5min.csv  91829  39476400.0  2731800.0  0.069201
# GFTYRV/EURUSDX_2025-09-05_to_2025-09-09_5m.csv    846    431700.0    29100.0  0.067408
#     GFTYRV/NDX_2025-10-05_to_2025-10-09_5m.csv    312    282300.0    18000.0  0.063762
# GFTYRV/EURUSDX_2025-09-30_to_2025-10-04_5m.csv   1134    339900.0    19500.0  0.057370
#    GFTYRV/GSPC_2025-10-05_to_2025-10-09_5m.csv    312    282300.0    15300.0  0.054198
#                     LMIRPG/EURUSD_5min_001.csv 524288 221086800.0 11956800.0  0.054082
#                     AY1PC8/EURUSD_1min_001.csv  50000   4331160.0   228120.0  0.052669
#     GFTYRV/NDX_2025-09-10_to_2025-09-14_5m.csv    232    195900.0    10200.0  0.052067
# GFTYRV/EURUSDX_2025-10-05_to_2025-10-09_5m.csv   1147    345300.0    16800.0  0.048653
#                    DO1H50/EURUSD_1hour_001.csv   5057  25916400.0  1220400.0  0.047090
#     GFTYRV/NDX_2025-09-05_to_2025-09-09_5m.csv    229    368700.0    16800.0  0.045566
#                       AY1PC8/EURUSD_1H_005.csv    840   4327200.0   190800.0  0.044093
# GFTYRV/EURUSDX_2025-10-20_to_2025-10-24_5m.csv   1422    426300.0    18600.0  0.043631
#    GFTYRV/GSPC_2025-10-20_to_2025-10-24_5m.csv    390    368700.0    15000.0  0.040683
#                       YH6M5S/EURUSD_1H_001.csv  30340 157762800.0  5835600.0  0.036990
#                       UZ2DPI/EURUSD_1H_001.csv    838   4050000.0   147600.0  0.036444
#    GFTYRV/GSPC_2025-09-25_to_2025-09-29_5m.csv    234    368700.0    13200.0  0.035801
#                        W241KQ/XAUUSD_30min.csv  69024 182134800.0  6217200.0  0.034135
#     GFTYRV/NDX_2025-09-15_to_2025-09-19_5m.csv    390    368700.0    12000.0  0.032547
#     GFTYRV/NDX_2025-09-30_to_2025-10-04_5m.csv    312    282300.0     8400.0  0.029756
#    GFTYRV/GSPC_2025-09-20_to_2025-09-24_5m.csv    234    195900.0     5700.0  0.029096
#                       VWXUD6/XAUUSD_5m_001.csv  13522   5871300.0   169200.0  0.028818
#                AS76HW/XAU_30m_data_limited.csv 242152 672323400.0 18662400.0  0.027758
#                     UZ2DPI/EURUSD_1min_001.csv   7197    604740.0    16740.0  0.027681
#    GFTYRV/GSPC_2025-09-30_to_2025-10-04_5m.csv    312    282300.0     7500.0  0.026567
#    GFTYRV/GSPC_2025-10-15_to_2025-10-19_5m.csv    234    195900.0     4800.0  0.024502
# GFTYRV/EURUSDX_2025-10-15_to_2025-10-19_5m.csv    846    253500.0     5400.0  0.021302
#    GFTYRV/GSPC_2025-10-10_to_2025-10-14_5m.csv    234    368700.0     6600.0  0.017901
#                     LMIRPG/EURUSD_5min_002.csv 524287 214592100.0  3685200.0  0.017173
#                    UZ2DPI/EURUSD_15min_001.csv   3342   4216500.0    67500.0  0.016009
#                     IJAKT3/EURUSD_1min_004.csv  43200   2591940.0    40140.0  0.015486
#     GFTYRV/NDX_2025-10-20_to_2025-10-24_5m.csv    390    368700.0     5700.0  0.015460
#                       VWXUD6/XAUUSD_5m_002.csv  13710   5871300.0    74100.0  0.012621
#                     UZ2DPI/EURUSD_5min_001.csv   7192   3023700.0    34500.0  0.011410
#                     IJAKT3/EURUSD_1min_002.csv  40320   2419140.0    26460.0  0.010938
#                AS76HW/XAU_15m_data_limited.csv 480717 672322500.0  6525900.0  0.009707
#                  DO1H50/EURUSD_1minute_001.csv  82033   6836340.0    64140.0  0.009382
#                     IJAKT3/EURUSD_1min_003.csv  44640   2678340.0    24900.0  0.009297
#                    UZ2DPI/EURUSD_30min_001.csv   1676   4487400.0    39600.0  0.008825
#                       Q5C0UO/EURUSD_5m_001.csv   6042   2595300.0    22500.0  0.008670
#                       Q5C0UO/EURUSD_1m_001.csv  30148   2595480.0    19140.0  0.007374
#                     IJAKT3/EURUSD_1min_001.csv  44640   2678340.0    19200.0  0.007169
#                 AS76HW/XAU_5m_data_limited.csv 999999 480823200.0  3408900.0  0.007090
#                     IJAKT3/EURUSD_1min_005.csv  44640   2678340.0    16320.0  0.006093
#                      Q5C0UO/EURUSD_30m_001.csv   1010   2593800.0    10800.0  0.004164
#                      Q5C0UO/EURUSD_15m_001.csv   2016   2594700.0     5400.0  0.002081
#                 AS76HW/XAU_1h_data_limited.csv 121823 672321600.0   738000.0  0.001098
# TYEGJ8/EURUSD_15min_001.csv label breakdown: {'Bearish Pennant': 29700.0, 'Bullish Pennant': 82800.0, 'Bullish Normal': 157500.0, 'Bearish Normal': 12600.0, 'Bullish Wedge': 64800.0}
# TYEGJ8/EURUSD_5min_002.csv label breakdown: {'Bullish Pennant': 41400.0, 'Bullish Normal': 74700.0, 'Bearish Normal': 51300.0, 'Bearish Pennant': 4200.0, 'Bullish Wedge': 6900.0}
# IV92EM/EURUSD_15min_001.csv label breakdown: {'Bearish Pennant': 553500.0, 'Bullish Normal': 144000.0, 'Bearish Normal': 277200.0, 'Bearish Wedge': 859500.0, 'Bullish Wedge': 360900.0, 'Bullish Pennant': 84600.0}
# GFTYRV/EURUSDX_2025-10-25_to_2025-10-29_5m.csv label breakdown: {'Bearish Pennant': 20400.0, 'Bullish Wedge': 12600.0, 'Bullish Normal': 11100.0, 'Bullish Pennant': 6600.0}
# TYEGJ8/US500_1min_003.csv label breakdown: {'Bearish Normal': 11520.0, 'Bullish Pennant': 3600.0, 'Bullish Normal': 59100.0, 'Bullish Wedge': 19380.0, 'Bearish Pennant': 4740.0, 'Bearish Wedge': 4380.0}
# W241KQ/EURUSD_15min.csv label breakdown: {'Bullish Pennant': 2881800.0, 'Bullish Normal': 21906900.0, 'Bearish Normal': 7299000.0, 'Bearish Pennant': 137700.0, 'Bullish Wedge': 128700.0}
# GFTYRV/EURUSDX_2025-10-30_to_2025-10-30_5m.csv label breakdown: {'Bullish Wedge': 7200.0}
# GFTYRV/EURUSDX_2025-09-15_to_2025-09-19_5m.csv label breakdown: {'Bearish Pennant': 9900.0, 'Bearish Wedge': 20400.0, 'Bullish Normal': 22500.0}
# GFTYRV/EURUSDX_2025-09-10_to_2025-09-14_5m.csv label breakdown: {'Bullish Normal': 4800.0, 'Bullish Wedge': 17100.0, 'Bearish Normal': 1800.0}
# AS76HW/XAU_1m_data_limited.csv label breakdown: {'Bullish Normal': 2538120.0, 'Bearish Wedge': 3789840.0, 'Bullish Pennant': 309720.0, 'Bullish Wedge': 59040.0, 'Bearish Normal': 5213040.0, 'Bearish Pennant': 1928760.0}
# GFTYRV/EURUSDX_2025-10-10_to_2025-10-14_5m.csv label breakdown: {'Bullish Wedge': 8400.0, 'Bearish Pennant': 13500.0, 'Bearish Wedge': 3900.0, 'Bullish Pennant': 11700.0}
# GFTYRV/NDX_2025-09-20_to_2025-09-24_5m.csv label breakdown: {'Bearish Pennant': 9900.0, 'Bearish Wedge': 6900.0}
# GFTYRV/NDX_2025-09-25_to_2025-09-29_5m.csv label breakdown: {'Bullish Normal': 6600.0, 'Bearish Normal': 7500.0, 'Bearish Pennant': 11700.0}
# GFTYRV/EURUSDX_2025-09-25_to_2025-09-29_5m.csv label breakdown: {'Bearish Normal': 5400.0, 'Bearish Pennant': 21600.0, 'Bullish Normal': 3000.0}
# W241KQ/EURUSD_5min.csv label breakdown: {'Bullish Normal': 673800.0, 'Bullish Wedge': 794400.0, 'Bullish Pennant': 312000.0, 'Bearish Normal': 871800.0, 'Bearish Wedge': 50100.0, 'Bearish Pennant': 29700.0}
# GFTYRV/EURUSDX_2025-09-05_to_2025-09-09_5m.csv label breakdown: {'Bearish Pennant': 6000.0, 'Bullish Wedge': 17700.0, 'Bullish Normal': 5400.0}
# GFTYRV/NDX_2025-10-05_to_2025-10-09_5m.csv label breakdown: {'Bearish Pennant': 18000.0}
# GFTYRV/EURUSDX_2025-09-30_to_2025-10-04_5m.csv label breakdown: {'Bearish Normal': 6000.0, 'Bearish Pennant': 5700.0, 'Bullish Pennant': 7800.0}
# GFTYRV/GSPC_2025-10-05_to_2025-10-09_5m.csv label breakdown: {'Bearish Wedge': 15300.0}
# LMIRPG/EURUSD_5min_001.csv label breakdown: {'Bearish Wedge': 1934100.0, 'Bearish Normal': 3015600.0, 'Bullish Normal': 5852700.0, 'Bullish Wedge': 1154400.0}
# AY1PC8/EURUSD_1min_001.csv label breakdown: {'Bearish Normal': 109260.0, 'Bearish Wedge': 21000.0, 'Bullish Wedge': 28920.0, 'Bearish Pennant': 9900.0, 'Bullish Normal': 49380.0, 'Bullish Pennant': 9660.0}
# GFTYRV/NDX_2025-09-10_to_2025-09-14_5m.csv label breakdown: {'Bullish Normal': 7500.0, 'Bullish Wedge': 2700.0}
# GFTYRV/EURUSDX_2025-10-05_to_2025-10-09_5m.csv label breakdown: {'Bearish Pennant': 9000.0, 'Bullish Pennant': 7800.0}
# DO1H50/EURUSD_1hour_001.csv label breakdown: {'Bullish Wedge': 176400.0, 'Bullish Normal': 601200.0, 'Bearish Normal': 306000.0, 'Bearish Wedge': 100800.0, 'Bullish Pennant': 36000.0}
# GFTYRV/NDX_2025-09-05_to_2025-09-09_5m.csv label breakdown: {'Bearish Wedge': 11100.0, 'Bearish Pennant': 5700.0}
# AY1PC8/EURUSD_1H_005.csv label breakdown: {'Bearish Normal': 64800.0, 'Bullish Normal': 126000.0}
# GFTYRV/EURUSDX_2025-10-20_to_2025-10-24_5m.csv label breakdown: {'Bullish Normal': 6600.0, 'Bullish Pennant': 12000.0}
# GFTYRV/GSPC_2025-10-20_to_2025-10-24_5m.csv label breakdown: {'Bullish Normal': 10200.0, 'Bullish Wedge': 4800.0}
# YH6M5S/EURUSD_1H_001.csv label breakdown: {'Bearish Normal': 1080000.0, 'Bullish Pennant': 698400.0, 'Bullish Normal': 1681200.0, 'Bearish Wedge': 1069200.0, 'Bearish Pennant': 1112400.0, 'Bullish Wedge': 194400.0}
# UZ2DPI/EURUSD_1H_001.csv label breakdown: {'Bearish Normal': 86400.0, 'Bullish Wedge': 14400.0, 'Bullish Normal': 32400.0, 'Bearish Wedge': 14400.0}
# GFTYRV/GSPC_2025-09-25_to_2025-09-29_5m.csv label breakdown: {'Bearish Pennant': 3600.0, 'Bearish Wedge': 5700.0, 'Bullish Pennant': 3900.0}
# W241KQ/XAUUSD_30min.csv label breakdown: {'Bullish Wedge': 680400.0, 'Bullish Normal': 3276000.0, 'Bearish Wedge': 388800.0, 'Bearish Normal': 1814400.0, 'Bullish Pennant': 57600.0}
# GFTYRV/NDX_2025-09-15_to_2025-09-19_5m.csv label breakdown: {'Bullish Normal': 12000.0}
# GFTYRV/NDX_2025-09-30_to_2025-10-04_5m.csv label breakdown: {'Bullish Pennant': 8400.0}
# GFTYRV/GSPC_2025-09-20_to_2025-09-24_5m.csv label breakdown: {'Bearish Normal': 5700.0}
# VWXUD6/XAUUSD_5m_001.csv label breakdown: {'Bullish Normal': 33000.0, 'Bullish Wedge': 27600.0, 'Bearish Normal': 56100.0, 'Bearish Wedge': 37200.0, 'Bearish Pennant': 4800.0, 'Bullish Pennant': 10500.0}
# AS76HW/XAU_30m_data_limited.csv label breakdown: {'Bearish Normal': 1393200.0, 'Bearish Wedge': 8640000.0, 'Bullish Wedge': 4444200.0, 'Bullish Normal': 3906000.0, 'Bearish Pennant': 279000.0}
# UZ2DPI/EURUSD_1min_001.csv label breakdown: {'Bearish Pennant': 2040.0, 'Bearish Normal': 7440.0, 'Bullish Normal': 3480.0, 'Bearish Wedge': 1200.0, 'Bullish Pennant': 900.0, 'Bullish Wedge': 1680.0}
# GFTYRV/GSPC_2025-09-30_to_2025-10-04_5m.csv label breakdown: {'Bearish Pennant': 7500.0}
# GFTYRV/GSPC_2025-10-15_to_2025-10-19_5m.csv label breakdown: {'Bullish Wedge': 4800.0}
# GFTYRV/EURUSDX_2025-10-15_to_2025-10-19_5m.csv label breakdown: {'Bullish Normal': 5400.0}
# GFTYRV/GSPC_2025-10-10_to_2025-10-14_5m.csv label breakdown: {'Bullish Pennant': 6600.0}
# LMIRPG/EURUSD_5min_002.csv label breakdown: {'Bearish Normal': 1071600.0, 'Bullish Wedge': 665100.0, 'Bullish Normal': 661200.0, 'Bearish Wedge': 817800.0, 'Bullish Pennant': 321900.0, 'Bearish Pennant': 147600.0}
# UZ2DPI/EURUSD_15min_001.csv label breakdown: {'Bearish Wedge': 8100.0, 'Bearish Normal': 31500.0, 'Bullish Normal': 27900.0}
# IJAKT3/EURUSD_1min_004.csv label breakdown: {'Bullish Normal': 8940.0, 'Bearish Pennant': 23280.0, 'Bearish Normal': 2640.0, 'Bullish Wedge': 2760.0, 'Bullish Pennant': 2520.0}
# GFTYRV/NDX_2025-10-20_to_2025-10-24_5m.csv label breakdown: {'Bullish Pennant': 5700.0}
# VWXUD6/XAUUSD_5m_002.csv label breakdown: {'Bearish Normal': 40500.0, 'Bullish Normal': 16200.0, 'Bearish Wedge': 8100.0, 'Bearish Pennant': 5700.0, 'Bullish Pennant': 3600.0}
# UZ2DPI/EURUSD_5min_001.csv label breakdown: {'Bearish Normal': 17700.0, 'Bullish Normal': 5400.0, 'Bullish Wedge': 3600.0, 'Bearish Pennant': 3000.0, 'Bearish Wedge': 4800.0}
# IJAKT3/EURUSD_1min_002.csv label breakdown: {'Bearish Wedge': 2580.0, 'Bullish Pennant': 4680.0, 'Bullish Wedge': 4620.0, 'Bearish Pennant': 8100.0, 'Bearish Normal': 4860.0, 'Bullish Normal': 1620.0}
# AS76HW/XAU_15m_data_limited.csv label breakdown: {'Bearish Normal': 4483800.0, 'Bearish Wedge': 877500.0, 'Bullish Wedge': 510300.0, 'Bearish Pennant': 200700.0, 'Bullish Normal': 453600.0}
# DO1H50/EURUSD_1minute_001.csv label breakdown: {'Bearish Normal': 10800.0, 'Bearish Wedge': 17760.0, 'Bullish Normal': 19920.0, 'Bullish Pennant': 4380.0, 'Bullish Wedge': 11280.0}
# IJAKT3/EURUSD_1min_003.csv label breakdown: {'Bearish Pennant': 4560.0, 'Bearish Wedge': 9120.0, 'Bullish Normal': 7200.0, 'Bullish Wedge': 4020.0}
# UZ2DPI/EURUSD_30min_001.csv label breakdown: {'Bearish Normal': 21600.0, 'Bullish Normal': 18000.0}
# Q5C0UO/EURUSD_5m_001.csv label breakdown: {'Bullish Normal': 15000.0, 'Bullish Pennant': 3300.0, 'Bearish Pennant': 2400.0, 'Bearish Normal': 1800.0}
# Q5C0UO/EURUSD_1m_001.csv label breakdown: {'Bullish Pennant': 5400.0, 'Bearish Normal': 1800.0, 'Bullish Normal': 5760.0, 'Bearish Pennant': 5460.0, 'Bullish Wedge': 720.0}
# IJAKT3/EURUSD_1min_001.csv label breakdown: {'Bearish Normal': 3480.0, 'Bullish Normal': 8520.0, 'Bullish Pennant': 2940.0, 'Bearish Wedge': 2640.0, 'Bearish Pennant': 1620.0}
# AS76HW/XAU_5m_data_limited.csv label breakdown: {'Bearish Normal': 835200.0, 'Bullish Wedge': 1441500.0, 'Bearish Wedge': 700500.0, 'Bullish Normal': 431700.0}
# IJAKT3/EURUSD_1min_005.csv label breakdown: {'Bearish Normal': 6960.0, 'Bullish Normal': 1140.0, 'Bullish Pennant': 1800.0, 'Bearish Pennant': 3780.0, 'Bearish Wedge': 2640.0}
# Q5C0UO/EURUSD_30m_001.csv label breakdown: {'Bullish Normal': 5400.0, 'Bullish Pennant': 5400.0}
# Q5C0UO/EURUSD_15m_001.csv label breakdown: {'Bullish Normal': 2700.0, 'Bearish Normal': 2700.0}
# AS76HW/XAU_1h_data_limited.csv label breakdown: {'Bearish Normal': 738000.0}

# %%
def trim_after_last_label(df: pd.DataFrame, label_col: str = "flag_label", margin: int = 64) -> pd.DataFrame:
    if df.shape[0] < 10000:
        return df
    
    mask = df[label_col] != label_map["No Flag"]
    last_labeled_idx = mask.to_numpy().nonzero()[0][-1]
    end_idx = min(len(df), last_labeled_idx + margin)
    return df.iloc[:end_idx].reset_index(drop=True)


def label_coverage(df: pd.DataFrame, label_col: str = "flag_label") -> dict[str, float]:
    total = len(df)
    if total == 0:
        return {"rows": 0, "labeled": 0, "coverage": 0.0}
    mask = df[label_col] != label_map["No Flag"]
    return {
        "rows": total,
        "labeled": int(mask.sum()),
        "coverage": float(mask.sum() / total),
    }

def print_coverage(file_name, stats_before, stats_after) -> None:
    print(f"{file_name} rows: {stats_before['rows']} rows: {stats_after['rows']}  coverage: {stats_before['coverage']:.3f} coverage: {stats_after['coverage']:.3f}")
    if stats_before['labeled'] != stats_after['labeled']:
        print(f"  Labeled rows changed from {stats_before['labeled']} to {stats_after['labeled']} after trimming.")

for file_name, content in data_with_labels.items():
    data = content["data"]
    labels = content["labels"]

    labeled_df = attach_interval_labels(data, labels, label_map)
    stats_before = label_coverage(labeled_df)
    labeled_df = trim_after_last_label(labeled_df, margin=32*2)
    stats_after = label_coverage(labeled_df)
    print_coverage(file_name, stats_before, stats_after)
# Out:
# AS76HW/XAU_1h_data_limited.csv rows: 121823 rows: 11152  coverage: 0.001 coverage: 0.014
# AS76HW/XAU_1m_data_limited.csv rows: 999999 rows: 969593  coverage: 0.095 coverage: 0.098
# AS76HW/XAU_5m_data_limited.csv rows: 999999 rows: 478257  coverage: 0.008 coverage: 0.017
# AS76HW/XAU_15m_data_limited.csv rows: 480717 rows: 432118  coverage: 0.011 coverage: 0.012
# AS76HW/XAU_30m_data_limited.csv rows: 242152 rows: 190510  coverage: 0.030 coverage: 0.038
# AY1PC8/EURUSD_1H_005.csv rows: 840 rows: 840  coverage: 0.067 coverage: 0.067
# AY1PC8/EURUSD_1min_001.csv rows: 50000 rows: 46398  coverage: 0.077 coverage: 0.083
# DO1H50/EURUSD_1hour_001.csv rows: 5057 rows: 5057  coverage: 0.068 coverage: 0.068
# DO1H50/EURUSD_1minute_001.csv rows: 82033 rows: 59607  coverage: 0.013 coverage: 0.018
# GFTYRV/GSPC_2025-09-25_to_2025-09-29_5m.csv rows: 234 rows: 234  coverage: 0.201 coverage: 0.201
# GFTYRV/GSPC_2025-09-30_to_2025-10-04_5m.csv rows: 312 rows: 312  coverage: 0.083 coverage: 0.083
# GFTYRV/GSPC_2025-10-05_to_2025-10-09_5m.csv rows: 312 rows: 312  coverage: 0.167 coverage: 0.167
# GFTYRV/GSPC_2025-10-10_to_2025-10-14_5m.csv rows: 234 rows: 234  coverage: 0.098 coverage: 0.098
# GFTYRV/GSPC_2025-10-15_to_2025-10-19_5m.csv rows: 234 rows: 234  coverage: 0.073 coverage: 0.073
# GFTYRV/GSPC_2025-10-20_to_2025-10-24_5m.csv rows: 390 rows: 390  coverage: 0.133 coverage: 0.133
# GFTYRV/NDX_2025-09-05_to_2025-09-09_5m.csv rows: 229 rows: 229  coverage: 0.253 coverage: 0.253
# GFTYRV/NDX_2025-09-10_to_2025-09-14_5m.csv rows: 232 rows: 232  coverage: 0.155 coverage: 0.155
# GFTYRV/NDX_2025-09-15_to_2025-09-19_5m.csv rows: 390 rows: 390  coverage: 0.105 coverage: 0.105
# GFTYRV/NDX_2025-09-20_to_2025-09-24_5m.csv rows: 234 rows: 234  coverage: 0.248 coverage: 0.248
# GFTYRV/NDX_2025-09-25_to_2025-09-29_5m.csv rows: 234 rows: 234  coverage: 0.380 coverage: 0.380
# GFTYRV/NDX_2025-09-30_to_2025-10-04_5m.csv rows: 312 rows: 312  coverage: 0.093 coverage: 0.093
# GFTYRV/NDX_2025-10-05_to_2025-10-09_5m.csv rows: 312 rows: 312  coverage: 0.196 coverage: 0.196
# GFTYRV/NDX_2025-10-20_to_2025-10-24_5m.csv rows: 390 rows: 390  coverage: 0.051 coverage: 0.051
# GFTYRV/GSPC_2025-09-20_to_2025-09-24_5m.csv rows: 234 rows: 234  coverage: 0.085 coverage: 0.085
# GFTYRV/EURUSDX_2025-09-05_to_2025-09-09_5m.csv rows: 846 rows: 846  coverage: 0.119 coverage: 0.119
# GFTYRV/EURUSDX_2025-09-10_to_2025-09-14_5m.csv rows: 846 rows: 846  coverage: 0.079 coverage: 0.079
# GFTYRV/EURUSDX_2025-09-15_to_2025-09-19_5m.csv rows: 1365 rows: 1365  coverage: 0.132 coverage: 0.132
# GFTYRV/EURUSDX_2025-09-25_to_2025-09-29_5m.csv rows: 846 rows: 846  coverage: 0.099 coverage: 0.099
# GFTYRV/EURUSDX_2025-09-30_to_2025-10-04_5m.csv rows: 1134 rows: 1134  coverage: 0.060 coverage: 0.060
# GFTYRV/EURUSDX_2025-10-05_to_2025-10-09_5m.csv rows: 1147 rows: 1147  coverage: 0.051 coverage: 0.051
# GFTYRV/EURUSDX_2025-10-10_to_2025-10-14_5m.csv rows: 846 rows: 846  coverage: 0.152 coverage: 0.152
# GFTYRV/EURUSDX_2025-10-15_to_2025-10-19_5m.csv rows: 846 rows: 846  coverage: 0.022 coverage: 0.022
# GFTYRV/EURUSDX_2025-10-20_to_2025-10-24_5m.csv rows: 1422 rows: 1422  coverage: 0.045 coverage: 0.045
# GFTYRV/EURUSDX_2025-10-25_to_2025-10-29_5m.csv rows: 863 rows: 863  coverage: 0.204 coverage: 0.204
# GFTYRV/EURUSDX_2025-10-30_to_2025-10-30_5m.csv rows: 136 rows: 136  coverage: 0.184 coverage: 0.184
# IJAKT3/EURUSD_1min_003.csv rows: 44640 rows: 43067  coverage: 0.010 coverage: 0.010
# IJAKT3/EURUSD_1min_004.csv rows: 43200 rows: 38466  coverage: 0.016 coverage: 0.018
# IJAKT3/EURUSD_1min_002.csv rows: 40320 rows: 38351  coverage: 0.011 coverage: 0.012
# IJAKT3/EURUSD_1min_001.csv rows: 44640 rows: 42570  coverage: 0.007 coverage: 0.008
# IJAKT3/EURUSD_1min_005.csv rows: 44640 rows: 44612  coverage: 0.006 coverage: 0.006
# IV92EM/EURUSD_15min_001.csv rows: 8201 rows: 8201  coverage: 0.174 coverage: 0.174
# LMIRPG/EURUSD_5min_001.csv rows: 524288 rows: 515054  coverage: 0.062 coverage: 0.064
# LMIRPG/EURUSD_5min_002.csv rows: 524287 rows: 485295  coverage: 0.024 coverage: 0.025
# Q5C0UO/EURUSD_30m_001.csv rows: 1010 rows: 1010  coverage: 0.008 coverage: 0.008
# Q5C0UO/EURUSD_15m_001.csv rows: 2016 rows: 2016  coverage: 0.004 coverage: 0.004
# Q5C0UO/EURUSD_5m_001.csv rows: 6042 rows: 6042  coverage: 0.014 coverage: 0.014
# Q5C0UO/EURUSD_1m_001.csv rows: 30148 rows: 29331  coverage: 0.012 coverage: 0.012
# TYEGJ8/EURUSD_15min_001.csv rows: 452 rows: 452  coverage: 0.675 coverage: 0.675
# TYEGJ8/EURUSD_5min_002.csv rows: 1355 rows: 1355  coverage: 0.370 coverage: 0.370
# TYEGJ8/US500_1min_003.csv rows: 1839 rows: 1839  coverage: 0.620 coverage: 0.620
# UZ2DPI/EURUSD_1H_001.csv rows: 838 rows: 838  coverage: 0.060 coverage: 0.060
# UZ2DPI/EURUSD_1min_001.csv rows: 7197 rows: 7197  coverage: 0.043 coverage: 0.043
# UZ2DPI/EURUSD_5min_001.csv rows: 7192 rows: 7192  coverage: 0.018 coverage: 0.018
# UZ2DPI/EURUSD_15min_001.csv rows: 3342 rows: 3342  coverage: 0.024 coverage: 0.024
# UZ2DPI/EURUSD_30min_001.csv rows: 1676 rows: 1676  coverage: 0.016 coverage: 0.016
# VWXUD6/XAUUSD_5m_001.csv rows: 13522 rows: 13251  coverage: 0.044 coverage: 0.045
# VWXUD6/XAUUSD_5m_002.csv rows: 13710 rows: 12595  coverage: 0.020 coverage: 0.022
# W241KQ/EURUSD_5min.csv rows: 91829 rows: 89775  coverage: 0.091 coverage: 0.094
# W241KQ/EURUSD_15min.csv rows: 143054 rows: 142099  coverage: 0.182 coverage: 0.183
# W241KQ/XAUUSD_30min.csv rows: 69024 rows: 66031  coverage: 0.043 coverage: 0.045
# YH6M5S/EURUSD_1H_001.csv rows: 30340 rows: 17272  coverage: 0.049 coverage: 0.086

# %% [markdown]
# Ez sem oldja meg a coverage problémát úgyhogy majd eldobjuk a nagyrészét az unlabeled windowknak
